# %% [markdown]
# # <font color='darkblue'> A. Import Github repository for the first time <font>

# %% [markdown]
# <font size="5"> (a) Connect to the Google Drive</font>

# %%
# "google.colab" is a library
# you will import the sublibrary "drive" which allows "Colab" to access your files

from google.colab import drive
drive.mount('/content/gdrive',force_remount = True)

# %% [markdown]
# <font size="5"> (b) Select the folder where you want to clone repository

# %%
# Import the "os" package to manage the directory
# Use the subcommand "chdir" to change the directory
# Enter your own folder
# In the tutorial we choose    "/content/gdrive/My Drive/emoryqtm151storage"

import os
os.chdir("/content/gdrive/My Drive/{yourdirectory}")

# %% [markdown]
# <font size="5"> (c) Delete any old versions of Github folder in your Google Drive. Then run the following command

# %% [markdown]
# (i) Follow instructions to create token on Canvas
#
# Make sure that your token is still active. Otherwise create a new one.

# %% [markdown]
# (ii) Clone repository, entering login details

# %%
# Replace {token} with your token, e.g. ghp_kCtN6wftQTBvnFFE
# Replace {username} with your user, e.g. johnsmith
# Replace {repository} with your repository name e.g. emoryqtm151
# The line should look something like this
#           !git clone ghp_kCtN6wftQTBvnFFEld@github.com/jonhsmith/emoryqtm151

# !git clone https://{token}}@github.com/{username}/{repository}.git
