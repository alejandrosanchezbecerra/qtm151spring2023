# %% [markdown]
# Before starting sometimes it's helpful to go to
# "Runtime" > "Restart runtime".
# This will clear the message from previous sessions.

# %% [markdown]
# # <font color='darkblue'> A. Connect to Google Drive <font>

# %%
# "google.colab" is a library
# you will import the sublibrary "drive" which allows "Colab" to access your files

from google.colab import drive
drive.mount('/content/gdrive',force_remount = True)

# %% [markdown]
# # <font color='darkblue'> B. Upload your own changes <font>

# %% [markdown]
# ## (i) Select the folder of the repository you want to update

# %% [markdown]
# <font color='red'> Make sure to enter your own folder  <font>

# %%
# Import the "os" package to manage the directory
# Use the subcommand "chdir" to change the directory
# Enter your own folder

import os
os.chdir("/content/gdrive/My Drive/emoryqtm151storage/emoryqtm151")

# %% [markdown]
# ## (ii) Commit your changes
#
# Commiting these changes first avoids problems later on.
# Sometimes there's a lag in recognizing the commits.
#
# <font color='red'> Add a custom message in the "commit" line.  <font>
#
# <font color='red'>This will help other users know what your changes were. <font>
#
#
# ---

# %%
# Edit your user details the for email and username
# These are the details that will appear on Github
# !git add .
# !git config --global user.email "you@example.com"
# !git config --global user.name "Your Name"

# CHANGE THE MESSAGE
# !git commit -m "Merge"

# Extra commands:
#            !git status     WILL CHECK FOR ANY CHANGES

# %% [markdown]
# ## (iii) Synchronse them to the cloud (pull any changes, push any changes)

# %%
# !git pull
# !git push

# %% [markdown]
# Congratulations, your files are now synchronized in the cloud!! You also should be able to pull the changes in "Github.com" and Github Desktop for all your devices.

# %% [markdown]
# Note: If your token is expired you may want to use the following code instead

# %%
# Get a new token from Github (see Canvas instructions)
# Replace this with your own {token}, {username}, and {repository}, respectively.
# ENTER your own  repository code

# !git fetch https://ghp_kCtN6wftQTBvnFFE@github.com/johnsmith/emoryqtm151.git main
# !git push https://ghp_kCtN6wftQTBvnFFEG@github.com/johnsmith/emoryqtm151.git main

# %% [markdown]
# # <font color='darkblue'> C. Update Lecture Notes <font>

# %% [markdown]
# <font color='red'> Before you proceed be warned that any modification to the lecture notes file could be overwritten  <font>
#
# <font color='red'> To avoid this problem, create a copy (with a different name) of files you want to modify <font>

# %% [markdown]
# (i) Select which repository to update from (check syllabus URL from the syllabus)
#
# If you've run this the first time, you might get a warning saying that "upstream" doesn't exist. Ignore it.

# %%
# !git remote rm upstream
# !git remote add upstream https://github.com/alejandrosanchezbecerra/qtm151spring2023.git

# %% [markdown]
# (ii) Update lecture notes

# %%
# The command "pull" will update
# It chooses "upstream" which is the name we gave to the class repository
# It will bring the information into "main" which is the 

# !git pull upstream main --no-commit

# We will manually create a commit
# When you see the commit history there will be two entries
#      one for the change in the lecture notes
#      a repeated entry for the merging process
# !git commit -m "Merge Lecture Notes in Google Colab"
# !git push
